# %%
import requests


def get_exchange_rate(base_currency, target_currency):
    """
    This function takes two currencies as input and returns the exchange rate between them.
    """
    # TODO: Implement the function to get the exchange rate between two currencies.
    # You can use an API or a database to get the exchange rates.
    # For now, we will just hardcode the exchange rates.

    # base_currency = 'USD'
    # target_currency = 'EUR'
    
    url = f'https://api.exchangerate-api.com/v4/latest/{base_currency}'

    response = requests.get(url)
    return response.json()['rates'][target_currency]

# %%
get_exchange_rate('EUR', 'USD')
# Out:
# 1.12

# %%
import requests

base_currency = 'USD'

url = f'https://api.exchangerate-api.com/v4/latest/{base_currency}'
response = requests.get(url)
list(response.json()['rates'].keys())
# Out:
# ['USD',
#  'AED',
#  'AFN',
#  'ALL',
#  'AMD',
#  'ANG',
#  'AOA',
#  'ARS',
#  'AUD',
#  'AWG',
#  'AZN',
#  'BAM',
#  'BBD',
#  'BDT',
#  'BGN',
#  'BHD',
#  'BIF',
#  'BMD',
#  'BND',
#  'BOB',
#  'BRL',
#  'BSD',
#  'BTN',
#  'BWP',
#  'BYN',
#  'BZD',
#  'CAD',
#  'CDF',
#  'CHF',
#  'CLP',
#  'CNY',
#  'COP',
#  'CRC',
#  'CUP',
#  'CVE',
#  'CZK',
#  'DJF',
#  'DKK',
#  'DOP',
#  'DZD',
#  'EGP',
#  'ERN',
#  'ETB',
#  'EUR',
#  'FJD',
#  'FKP',
#  'FOK',
#  'GBP',
#  'GEL',
#  'GGP',
#  'GHS',
#  'GIP',
#  'GMD',
#  'GNF',
#  'GTQ',
#  'GYD',
#  'HKD',
#  'HNL',
#  'HRK',
#  'HTG',
#  'HUF',
#  'IDR',
#  'ILS',
#  'IMP',
#  'INR',
#  'IQD',
#  'IRR',
#  'ISK',
#  'JEP',
#  'JMD',
#  'JOD',
#  'JPY',
#  'KES',
#  'KGS',
#  'KHR',
#  'KID',
#  'KMF',
#  'KRW',
#  'KWD',
#  'KYD',
#  'KZT',
#  'LAK',
#  'LBP',
#  'LKR',
#  'LRD',
#  'LSL',
#  'LYD',
#  'MAD',
#  'MDL',
#  'MGA',
#  'MKD',
#  'MMK',
#  'MNT',
#  'MOP',
#  'MRU',
#  'MUR',
#  'MVR',
#  'MWK',
#  'MXN',
#  'MYR',
# ...

# %%
def convert_currency(amount, exchange_rate):
    return amount * exchange_rate

# %%
base_currency = "USD"
target_currency = "EUR"
amount = 100

print(f"Converting {amount} {base_currency} to {target_currency}...")

# API call to get the exchange rate

# %%
# %pip install currencies
# Out:
# ...
#   Obtaining dependency information for currencies from https://files.pythonhosted.org/packages/c4/0f/98b4efae4f0e39dfa9d434cb8b4b55e547eff290ab5b752d10f38f8ba376/currencies-2020.12.12-py3-none-any.whl.metadata
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import currencies


list(currencies.MONEY_FORMATS.keys())
# Out:
# ['AED',
#  'AFN',
#  'ALL',
#  'AMD',
#  'ANG',
#  'AOA',
#  'ARS',
#  'AUD',
#  'AWG',
#  'AZN',
#  'BAM',
#  'BBD',
#  'BDT',
#  'BGN',
#  'BHD',
#  'BND',
#  'BOB',
#  'BRL',
#  'BSD',
#  'BTN',
#  'BWP',
#  'BYR',
#  'BZD',
#  'CAD',
#  'CHF',
#  'CLP',
#  'CNY',
#  'COP',
#  'CRC',
#  'CZK',
#  'DKK',
#  'DOP',
#  'DZD',
#  'EGP',
#  'ETB',
#  'EUR',
#  'FJD',
#  'GBP',
#  'GEL',
#  'GHS',
#  'GMD',
#  'GTQ',
#  'GYD',
#  'HKD',
#  'HNL',
#  'HRK',
#  'HUF',
#  'IDR',
#  'ILS',
#  'INR',
#  'ISK',
#  'JEP',
#  'JMD',
#  'JOD',
#  'JPY',
#  'KES',
#  'KGS',
#  'KHR',
#  'KRW',
#  'KWD',
#  'KYD',
#  'KZT',
#  'LBP',
#  'LKR',
#  'LTL',
#  'LVL',
#  'MAD',
#  'MDL',
#  'MGA',
#  'MKD',
#  'MMK',
#  'MNT',
#  'MOP',
#  'MUR',
#  'MVR',
#  'MXN',
#  'MYR',
#  'MZN',
#  'NAD',
#  'NGN',
#  'NIO',
#  'NOK',
#  'NPR',
#  'NZD',
#  'OMR',
#  'PEN',
#  'PGK',
#  'PHP',
#  'PKR',
#  'PLN',
#  'PYG',
#  'QAR',
#  'RON',
#  'RSD',
#  'RUB',
#  'RWF',
#  'SAR',
#  'SCR',
#  'SEK',
#  'SGD',
# ...

# %%
# %pip install cachetools
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
